# %% [markdown]
# <a href="https://colab.research.google.com/github/cyrus723/my-first-binder/blob/main/EPL_datahub_io_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data source: EPL data from https://datahub.io/sports-data/english-premier-league#data-cli

# %%
pip install datapackage
# Out:
# ...
#      |████████████████████████████████| 85 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 72 kB 188 kB/s
# ...
#      |████████████████████████████████| 68 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 41 kB 532 kB/s
# ...
#      |████████████████████████████████| 126 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 132 kB 9.7 MB/s
# ...
#      |████████████████████████████████| 8.7 MB 10.3 MB/s
# ...
#      |████████████████████████████████| 79 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 127 kB 64.1 MB/s
# ...
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7400 sha256=3d459206fbf9884307c8fc609d3bfef7465fb3c0a87636f57ae7d473943eec3d
#   Stored in directory: /root/.cache/pip/wheels/dd/0a/62/49ee84fab92057fb3e303fb1a59e75ccac6899b417f441305a
# ...
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10768 sha256=f80820d56be9061f4a7b1985aa1b809abe4b65f3b9ee04c138de1fc36c2af7ee
# ...

# %%
import datapackage
import pandas as pd

data_url = 'https://datahub.io/sports-data/english-premier-league/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        print (data)
# Out:
#     Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1    E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2    E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3    E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4    E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
# ..   ..         ...           ...             ...   ...   ...  ..   ...   ...
# 375  E0  12/05/2019     Liverpool          Wolves     2     0   H     1     0
# 376  E0  12/05/2019    Man United         Cardiff     0     2   A     0     1
# 377  E0  12/05/2019   Southampton    Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019     Tottenham         Everton     2     2   D     1     0
# 379  E0  12/05/2019       Watford        West Ham     1     4   A     0     2
#
# ...

# %%
package

# %%
print(package)

# %%
print(resource)

# %%
data
# Out:
#     Div        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0  2009-08-15  Aston Villa       Wigan     0     2   A     0     1   A
# 1    E0  2009-08-15    Blackburn    Man City     0     2   A     0     1   A
# 2    E0  2009-08-15       Bolton  Sunderland     0     1   A     0     1   A
# 3    E0  2009-08-15      Chelsea        Hull     2     1   H     1     1   D
# 4    E0  2009-08-15      Everton     Arsenal     1     6   A     0     3   A
# ..   ..         ...          ...         ...   ...   ...  ..   ...   ...  ..
# 375  E0  2010-05-09      Everton  Portsmouth     1     0   H     0     0   D
# 376  E0  2010-05-09         Hull   Liverpool     0     0   D     0     0   D
# 377  E0  2010-05-09   Man United       Stoke     4     0   H     2     0   H
# 378  E0  2010-05-09     West Ham    Man City     1     1   D     1     1   D
# 379  E0  2010-05-09       Wolves  Sunderland     2     1   H     1     1   D
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 71 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
# ...

# %%
data.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.697368    1.073684    0.744737    0.471053   13.728947   10.718421
# std      1.467500    1.122964    0.825452    0.694269    5.379793    4.510577
# min      0.000000    0.000000    0.000000    0.000000    2.000000    2.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    7.000000
# 50%      2.000000    1.000000    1.000000    0.000000   12.500000   10.000000
# 75%      2.000000    2.000000    1.000000    1.000000   17.000000   13.000000
# max      9.000000    6.000000    4.000000    5.000000   33.000000   27.000000
#
#               HST         AST          HF          AF  ...    BbMx>2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     7.723684    5.928947   11.639474   12.555263  ...    1.999553
# ...

# %%
from datapackage import Package

package = Package('https://datahub.io/sports-data/english-premier-league/datapackage.json')

# print list of all resources:
print(package.resource_names)

# print processed tabular data (if exists any)
for resource in package.resources:
    if resource.descriptor['datahub']['type'] == 'derived/csv':
        print(resource.read())
# Out:
# ['validation_report', 'season-1819_csv', 'season-1718_csv', 'season-1617_csv', 'season-1516_csv', 'season-1415_csv', 'season-1314_csv', 'season-1213_csv', 'season-1112_csv', 'season-1011_csv', 'season-0910_csv', 'season-1819_json', 'season-1718_json', 'season-1617_json', 'season-1516_json', 'season-1415_json', 'season-1314_json', 'season-1213_json', 'season-1112_json', 'season-1011_json', 'season-0910_json', 'english-premier-league_zip', 'season-1819', 'season-1718', 'season-1617', 'season-1516', 'season-1415', 'season-1314', 'season-1213', 'season-1112', 'season-1011', 'season-0910']
# ...

# %%
print(package.resource_names)
# Out:
# ['validation_report', 'season-1819_csv', 'season-1718_csv', 'season-1617_csv', 'season-1516_csv', 'season-1415_csv', 'season-1314_csv', 'season-1213_csv', 'season-1112_csv', 'season-1011_csv', 'season-0910_csv', 'season-1819_json', 'season-1718_json', 'season-1617_json', 'season-1516_json', 'season-1415_json', 'season-1314_json', 'season-1213_json', 'season-1112_json', 'season-1011_json', 'season-0910_json', 'english-premier-league_zip', 'season-1819', 'season-1718', 'season-1617', 'season-1516', 'season-1415', 'season-1314', 'season-1213', 'season-1112', 'season-1011', 'season-0910']

# %%
 print(resource.read())
# Out:
# [['E0', datetime.date(2009, 8, 15), 'Aston Villa', 'Wigan', 0, 2, 'A', 0, 1, 'A', 'M Clattenburg', 11, 14, 5, 7, 15, 14, 4, 6, 2, 2, 0, 0, Decimal('1.67'), Decimal('3.6'), Decimal('5.5'), Decimal('1.65'), Decimal('3.4'), Decimal('5'), Decimal('1.67'), Decimal('3.5'), Decimal('5.25'), Decimal('1.7'), Decimal('3.5'), Decimal('4.9'), Decimal('1.67'), Decimal('3.3'), Decimal('4.5'), Decimal('1.65'), Decimal('3.4'), Decimal('5'), Decimal('1.7'), Decimal('3.4'), Decimal('5.5'), Decimal('1.67'), Decimal('3.6'), Decimal('5.5'), Decimal('1.7'), Decimal('3.4'), Decimal('5'), Decimal('1.62'), Decimal('3.5'), Decimal('5.5'), 37, Decimal('1.72'), Decimal('1.66'), Decimal('3.77'), Decimal('3.51'), Decimal('6.05'), Decimal('5.33'), 32, Decimal('2.04'), Decimal('1.92'), Decimal('1.91'), Decimal('1.81'), 21, Decimal('0'), Decimal('1.28'), Decimal('1.22'), Decimal('4.4'), Decimal('3.99')], ['E0', datetime.date(2009, 8, 15), 'Blackburn', 'Man City', 0, 2, 'A', 0, 1, 'A', 'M Dean', 17, 8, 9, 5, 12, 9, 5
# ...
